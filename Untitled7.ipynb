# %%
#part2


import requests
from bs4 import BeautifulSoup
url="https://www.ptt.cc/bbs/NBA/index.html"

def get_all_href(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")

container = soup.select('.r-ent')

for each_item in container:

     print ("日期："+each_item.select('div.date')[0].text) 
        
     print("作者："+each_item.select('div.author')[0].text)
     print (each_item.select('div.title')[0].text)

     print ("..............")
# Out:
# 日期： 4/09
# 作者：love1500274
#
# [情報] 熱火裁掉McGruder 及 未來兩年薪資上限
#
# ..............
# 日期： 4/09
# 作者：godiegroup
#
# [新聞]最年輕MVP重返風城?羅斯透露新賽季去向
#
# ..............
# 日期： 4/09
# 作者：iammatrix
#
# Re: [情報] James:與Kobe的比較並不公平，退役湖人球
#
# ..............
# 日期： 4/09
# 作者：kenny1300175
#
# [花邊] KI不排斥再與詹皇聯手？美名嘴爆他今夏願與湖人見面
#
# ..............
# 日期： 4/09
# 作者：thnlkj0665
#
# [情報] Giannis Antetokounmpo 婉拒演出怪物奇兵
#
# ..............
# 日期： 4/09
# 作者：qwerty789
#
# [討論] 2017梯選秀深度
#
# ..............
# 日期： 4/10
# 作者：JoelEmbiid
#
# [外絮] Marks:small stepping stone for Nets
#
# ..............
# 日期： 4/10
# 作者：kenny1300175
#
# [外絮] 公牛差點將Jabari交易到LA換KCP+Beasley
#
# ..............
# 日期： 4/10
# 作者：-
#
#
# 				(本文已被刪除) [beck600325]
#
#
# ..............
# 日期： 4/10
# 作者：TheoEpstein
#
# Re: [外絮] 公牛差點將Jabari交易到LA換KCP+Beasley
#
# ..............
# 日期： 4/10
# 作者：TomasMao
#
# [外絮] Kyle Korver-特權 (下)
#
# ..............
# 日期： 4/10
# 作者：Costco5566
#
# [花邊] Wade和五位神秘嘉賓換衣服
#
# ..............
# 日期： 4/10
# 作者：blacklittle
#
# [花邊] DSJ: Dirk還欠我錢
#
# ..............
# 日期： 4/10
# 作者：Rambo
#
# [Live] 灰熊 @ 活塞
#
# ..............
# 日期： 4/10
# 作者：Rambo
#
# [Live] 超賽 @ 巫師
#
# ..............
# 日期： 4/10
# 作者：Rambo
#
# [Live] 七六人 @ 熱火
#
# ..............
# 日期： 4/10
# 作者：Rambo
#
# [Live] 暴龍 @ 灰狼
#
# ..............
# 日期： 4/10
# 作者：Rambo
#
# [Live] 勇士 @ 鵜鶘
#
# ..............
# 日期： 4/10
# 作者：Rambo
#
# [Live] 尼克 @ 公牛
#
# ..............
# 日期： 4/10
# 作者：Rambo
#
# [Live] 黃蜂 @ 騎士
#
# ..............

# %%
#part1

total_sum = 0
for i in range(1000):
    if (i%3 == 0 or i%5 == 0):
        total_sum = total_sum+i
print total_sum
# Out:
#   File "<ipython-input-29-eafb7c8387fc>", line 4
#     var sum = 0, i = 1;
#           ^
# SyntaxError: invalid syntax
